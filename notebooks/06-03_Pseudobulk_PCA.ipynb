# %%
import os
import sys

if os.getcwd().endswith("notebooks"):
    os.chdir("..")

sys.path.append(os.path.abspath("./"))

print(f"Current work directory: {os.getcwd()}")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
import os
from scripts.plotting import plot_pca_scatter

# %%
all = pd.read_csv('./Pseudobulk/pca.csv')
variance = pd.read_csv('./Pseudobulk/variance.csv')

# %%
all['group'] = all['sample'].str.split('_').str[0]

# %%
order = ['No infection','Low infection','High infection']
custom_palette = {
    'No infection':   '#ec5e60',
    'Low infection':  '#72a4cd',
    'High infection': '#82c680',
}
fig, ax = plot_pca_scatter(
    all_df=all,
    variance_df=variance,
    title='Pseudo bulk - OC43 HEK293T single cell',
    order=order,
    save_path='./Plot/Pesudo bulk - OC43 HEK293T single cell_260609.png',
    palette=custom_palette    
)
plt.show()

# %%
import session_info

session_info.show()
